# %% [markdown]
# <a href="https://colab.research.google.com/github/mlfigueiredo/CienciaDosDados/blob/main/Bolsa_de_valores_com_gr%C3%A1ficos_PLOT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import plotly
import plotly.offline as py

# %%
from plotly.offline import plot, iplot
plotly.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.8.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import pandas as pd
df=pd.read_csv('/content/acao petrobras.csv')

# %%
df.head()
# Out:
#          Date   Open   High    Low  Close  Adj Close    Volume
# 0  2017-04-24  14.13  14.16  13.92  14.03   9.678646  27546200
# 1  2017-04-25  13.90  14.34  13.80  14.34   9.892499  32268100
# 2  2017-04-26  14.16  14.49  14.00  14.00   9.657948  37045000
# 3  2017-04-27  13.99  14.03  13.56  13.73   9.471689  29078500
# 4  2017-04-28  13.85  14.10  13.69  13.97   9.637255  31061200

# %%
df.shape
# Out:
# (1243, 7)

# %%
import plotly.io as pio
pio.renderers
# Out:
# Renderers configuration
# -----------------------
#     Default renderer: 'plotly_mimetype+notebook_connected'
#     Available renderers:
#         ['plotly_mimetype', 'jupyterlab', 'nteract', 'vscode',
#          'notebook', 'notebook_connected', 'kaggle', 'azure', 'colab',
#          'cocalc', 'databricks', 'json', 'png', 'jpeg', 'jpg', 'svg',
#          'pdf', 'browser', 'firefox', 'chrome', 'chromium', 'iframe',
#          'iframe_connected', 'sphinx_gallery', 'sphinx_gallery_png']

# %%
pio.renderers.default='colab'

# %%
import plotly.graph_objs as go
data= [go.Scatter(x=df.Date, y=df.Close)]
py.iplot(data)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7d5c1615-c5b6-4838-8cdd-01f50ba2e4b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d5c1615-c5b6-4838-8cdd-01f50ba2e4b2")) {                    Plotly.newPlot(                        "7d5c1615-c5b6-4838-8cdd-01f50ba2e4b2",                        [{"x":["2017-04-24","2017-04-25","2017-04-26","2017-04-27","2017-04-28","2017-05-02","2017-05-03","2017-05-04","2017-05-05","2017-05-08","2017-05-09","2017-05-10","2017-05-11","2017-05-12","2017-05-15","2017-05-16","2017-05-17","2017-05-18","2017-05-19","2017-05-22","2017-05-23","2017-05-24","2017-05-25","2017-05-26","2017-05-29","2017-05-30","2017-05-31","2017-06-01","2017-06-02","2017-06-05","2017-06-06","2017-06-07","2017-06-08","2017-06-09","2017-06-12","2017-06-13","2017-06-14","2017-06-15","2017-06-16","2017-06-19","2017-06-20","2017-06-21","2017-06-22","2017-06-23","2017-06-26","2017-06-27","2017-06-28","2017-06-29","2017-06-30","2017-07-03","2017-07-04","2017-07-05","2017-07-06","2017-07-07","2017-07-10","2017-07-11","2017-07-12","2017-07-13","2017-07-14","2017-07-17","2017-07-18","2017-07-19","2017-07-20","2017-07-21","2017-07-24","2017-07-25","2017-07-26","2017-07-27","2017-07-28","2017-07-31","2017-08-01","2017-08-02","2017-08-03","2017-08-04","2017-08-07","2017-08-08","2017-08-09","2017-08-10","2017-08-11","2017-08-14","2017-08-15","2017-08-16","2017-08-17","2017-08-18","2017-08-21","2017-08-22","2017-08-23","2017-08-24","2017-08-25","2017-08-28","2017-08-29","2017-08-30","2017-08-31","2017-09-01","2017-09-04","2017-09-05","2017-09-06","2017-09-07","2017-09-08","2017-09-11","2017-09-12","2017-09-13","2017-09-14","2017-09-15","2017-09-18","2017-09-19","2017-09-20","2017-09-21","2017-09-22","2017-09-25","2017-09-26","2017-09-27","2017-09-28","2017-09-29","2017-10-02","2017-10-03","2017-10-04","2017-10-05","2017-10-06","2017-10-09","2017-10-10","2017-10-11","2017-10-12","2017-10-13","2017-10-16","2017-10-17","2017-10-18","2017-10-19","2017-10-20","2017-10-23","2017-10-24","2017-10-25","2017-10-26","2017-10-27","2017-10-30","2017-10-31","2017-11-01","2017-11-02","2017-11-03","2017-11-06","2017-11-07","2017-11-08","2017-11-09","2017-11-10","2017-11-13","2017-11-14","2017-11-15","2017-11-16","2017-11-17","2017-11-20","2017-11-21","2017-11-22","2017-11-23","2017-11-24","2017-11-27","2017-11-28","2017-11-29","2017-11-30","2017-12-01","2017-12-04","2017-12-05","2017-12-06","2017-12-07","2017-12-08","2017-12-11","2017-12-12","2017-12-13","2017-12-14","2017-12-15","2017-12-18","2017-12-19","2017-12-20","2017-12-21","2017-12-22","2017-12-25","2017-12-26","2017-12-27","2017-12-28","2017-12-29","2018-01-02","2018-01-03","2018-01-04","2018-01-05","2018-01-08","2018-01-09","2018-01-10","2018-01-11","2018-01-12","2018-01-15","2018-01-16","2018-01-17","2018-01-18","2018-01-19","2018-01-22","2018-01-23","2018-01-24","2018-01-25","2018-01-26","2018-01-29","2018-01-30","2018-01-31","2018-02-01","2018-02-02","2018-02-05","2018-02-06","2018-02-07","2018-02-08","2018-02-09","2018-02-14","2018-02-15","2018-02-16","2018-02-19","2018-02-20","2018-02-21","2018-02-22","2018-02-23","2018-02-26","2018-02-27","2018-02-28","2018-03-01","2018-03-02","2018-03-05","2018-03-06","2018-03-07","2018-03-08","2018-03-09","2018-03-12","2018-03-13","2018-03-14","2018-03-15","2018-03-16","2018-03-19","2018-03-20","2018-03-21","2018-03-22","2018-03-23","2018-03-26","2018-03-27","2018-03-28","2018-03-29","2018-04-02","2018-04-03","2018-04-04","2018-04-05","2018-04-06","2018-04-09","2018-04-10","2018-04-11","2018-04-12","2018-04-13","2018-04-16","2018-04-17","2018-04-18","2018-04-19","2018-04-20","2018-04-23","2018-04-24","2018-04-25","2018-04-26","2018-04-27","2018-04-30","2018-05-02","2018-05-03","2018-05-04","2018-05-07","2 ...

# %%
import plotly.graph_objs as go
import matplotlib.pyplot as plt

Close= [go.Scatter(
                  x=df.Date, 
                  y=df.Close, 
                  name= 'Petr4 Close', 
                  line= dict(color='#000000'), 
                  opacity=0.8
                  )
        ]
data=[Close]
layout= dict(
    title='Faixa de Data Customizada',  
    title_x=0.5,
    x_axis=dict(
        range=['2017-01-01', '2017-12-31'])
    )
fig= dict(data=data, layout=layout)
py.iplot(Close)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-57e7db063be8> in <module>()
#      17         range=['2017-01-01', '2017-12-31'])
#      18     )
# ---> 19 fig= go.Figure(data=data, layout=layout)
#      20 py.iplot(fig)
#
# /usr/local/lib/python3.7/dist-packages/plotly/graph_objs/_figure.py in __init__(self, data, layout, frames, skip_invalid, **kwargs)
#     592             is invalid AND skip_invalid is False
#     593         """
# --> 594         super(Figure, self).__init__(data, layout, frames, skip_invalid, **kwargs)
#     595
#     596     def add_bar(
#
# /usr/local/lib/python3.7/dist-packages/plotly/basedatatypes.py in __init__(self, data, layout_plotly, frames, skip_invalid, **kwargs)
#     515         # ### Import traces ###
#     516         data = self._data_validator.validate_coerce(
# --> 517             data, skip_invalid=skip_invalid, _validate=self._validate
#     518         )
#     519
#
# /usr/local/lib/python3.7/dist-packages/_plotly_utils/basevalidators.py in validate_coerce(self, v, skip_invalid, _validate)
#    2692
#    2693             if invalid_els:
# -> 2694                 self.raise_invalid_elements(invalid_els)
#    2695
#    2696             v = to_scalar_or_list(res)
#
# /usr/local/lib/python3.7/dist-packages/_plotly_utils/basevalidators.py in raise_invalid_elements(self, invalid_els)
#     312                     pname=self.parent_name,
#     313                     invalid=invalid_els[:10],
# --> 314                     valid_clr_desc=self.description(),
#     315                 )
#     316             )
#
# ValueError:
#     Invalid element(s) received for the 'data' property of
#         Invalid elements include: [[Scatter({
#     'line': {'color': '#000000'},
#     'name': 'Petr4 Close',
#     'opacity': 0.8,
#     'x': array(['2017-04-24', '2017-04-25', '2017-04-26', ..., '2022-04-18',
#                 '2022-04-19', '2022-04-20'], dtype=object),
#     'y': array([14.03    , 14.34    , 14.      , ..., 30.719999, 31.65    , 31.799999])
# })]]
#
#     The 'data' property is a tuple of trace instances
#     that may be specified as:
#       - A list or tuple of trace instances
#         (e.g. [Scatter(...), Bar(...)])
#       - A single trace instance
#         (e.g. Scatter(...), Bar(...), etc.)
#       - A list or tuple of dicts of string/value properties where:
#         - The 'type' property specifies the trace type
#             One of: ['bar', 'barpolar', 'box', 'candlestick',
#                      'carpet', 'choropleth', 'choroplethmapbox',
#                      'cone', 'contour', 'contourcarpet',
#                      'densitymapbox', 'funnel', 'funnelarea',
#                      'heatmap', 'heatmapgl', 'histogram',
#                      'histogram2d', 'histogram2dcontour', 'icicle',
#                      'image', 'indicator', 'isosurface', 'mesh3d',
#                      'ohlc', 'parcats', 'parcoords', 'pie',
#                      'pointcloud', 'sankey', 'scatter',
#                      'scatter3d', 'scattercarpet', 'scattergeo',
#                      'scattergl', 'scattermapbox', 'scatterpolar',
#                      'scatterpolargl', 'scattersmith',
#                      'scatterternary', 'splom', 'streamtube',
#                      'sunburst', 'surface', 'table', 'treemap',
#                      'violin', 'volume', 'waterfall']
#
#         - All remaining properties are passed to the constructor of
#           the specified trace type
#
#         (e.g. [{'type': 'scatter', ...}, {'type': 'bar, ...}])

# %%
trace= go.Candlestick(x=df.Date,
                      open=df.Open,
                      high=df.High,
                      low=df.Low,
                      close=df.Close)
data = [trace]
py.iplot(data, filename='cladlestick')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="468f010b-438a-42e8-9618-0271e7b4760d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("468f010b-438a-42e8-9618-0271e7b4760d")) {                    Plotly.newPlot(                        "468f010b-438a-42e8-9618-0271e7b4760d",                        [{"close":[14.03,14.34,14.0,13.73,13.97,13.99,14.16,13.6,14.21,14.08,14.14,14.73,14.82,15.45,15.68,15.7,15.61,13.15,13.62,13.4,13.49,14.05,13.74,13.68,13.68,13.36,12.96,12.82,13.05,13.18,13.18,12.87,12.84,12.85,12.9,12.94,12.62,12.62,12.28,12.29,11.86,11.64,12.04,11.93,12.27,12.21,12.08,12.18,12.37,12.36,12.43,12.21,12.17,11.93,11.98,12.33,12.94,12.87,13.05,12.89,12.94,13.23,13.1,12.69,12.88,13.22,13.06,13.0,13.13,13.29,13.12,13.51,13.31,13.4,13.55,13.49,13.52,13.19,12.95,13.08,13.15,13.13,13.05,13.6,13.34,13.79,13.76,13.8,13.88,13.87,13.85,13.45,13.65,14.02,
# %%
trace= go.Candlestick(x=df.Date,
                      open=df.Open,
                      high=df.High,
                      low=df.Low,
                      close=df.Close)
layout={
    'title':'Preços no periodo',
    'title_x':0.5,
    'yaxis': {'title':'Petr4 preço'},
    'annotations': [{
        'x':'2017-05-17',
        'y':17,
        'xref':'x',
        'yref':'y',
        'showarrow':True,
        'font': dict(
            family='Courier New monospace',
            size=12
        ),
        'text':'Audio Joesley',
        'align':'center',
        'arrowhead':2,
        'arrowsize':1,
        'arrowwidth':2,
        'bordercolor':'#c7c7c7',
        'borderwidth':4
    },
    {
        'x':'2016-01-07',
        'y':7,
        'xref':'x',
        'yref':'y',
        'showarrow':True,
        'font': dict(
            family='Courier New monospace',
            size=12
        ),
        'text':'Impeachment Dilma',
        'align':'center',
        'arrowhead':2,
        'arrowsize':1,
        'arrowwidth':2,
        'bordercolor':'#c7c7c7',
        'borderwidth':4
    },
    {
        'x':'2018-05-27',
        'y':27,
        'xref':'x',
        'yref':'y',
        'showarrow':True,
        'font': dict(
            family='Courier New monospace',
            size=12
        ),
        'text':'Greve dos caminhoneiros',
        'align':'center',
        'arrowhead':2,
        'arrowsize':1,
        'arrowwidth':2,
        'bordercolor':'#c7c7c7',
        'borderwidth':4
    }
    ]}
data = [trace]
fig=dict(data=data, layout=layout)
py.iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7598c89e-7e6c-43ef-bc47-ad498b2bc61e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7598c89e-7e6c-43ef-bc47-ad498b2bc61e")) {                    Plotly.newPlot(                        "7598c89e-7e6c-43ef-bc47-ad498b2bc61e",                        [{"close":[14.03,14.34,14.0,13.73,13.97,13.99,14.16,13.6,14.21,14.08,14.14,14.73,14.82,15.45,15.68,15.7,15.61,13.15,13.62,13.4,13.49,14.05,13.74,13.68,13.68,13.36,12.96,12.82,13.05,13.18,13.18,12.87,12.84,12.85,12.9,12.94,12.62,12.62,12.28,12.29,11.86,11.64,12.04,11.93,12.27,12.21,12.08,12.18,12.37,12.36,12.43,12.21,12.17,11.93,11.98,12.33,12.94,12.87,13.05,12.89,12.94,13.23,13.1,12.69,12.88,13.22,13.06,13.0,13.13,13.29,13.12,13.51,13.31,13.4,13.55,13.49,13.52,13.19,12.95,13.08,13.15,13.13,13.05,13.6,13.34,13.79,13.76,13.8,13.88,13.87,13.85,13.45,13.65,14.02,14.17,14.41,15.02,15.02,14.71,14.99,14.87,15.03,15.04,15.04,15.04,15.14,15.87,15.67,15.69,15.84,15.56,15.31,15.34,15.3,15.4,15.98,15.66,15.9,15.69,15.89,16.190001,16.08,16.08,16.08,16.120001,16.129999,16.16,16.15,16.219999,16.200001,16.51,16.719999,16.73,17.030001,16.780001,16.77,16.9,16.9,16.940001,17.43,16.5,16.950001,16.719999,16.719999,16.639999,15.35,15.35,15.81,16.02,16.02,15.9,16.110001,16.190001,16.1,15.87,15.84,
# Out:
#           Date   Open   High    Low  Close  Adj Close     Volume       MM_9  \
# 0   2017-04-24  14.13  14.16  13.92  14.03   9.678646   27546200        NaN
# 1   2017-04-25  13.90  14.34  13.80  14.34   9.892499   32268100        NaN
# 2   2017-04-26  14.16  14.49  14.00  14.00   9.657948   37045000        NaN
# 3   2017-04-27  13.99  14.03  13.56  13.73   9.471689   29078500        NaN
# 4   2017-04-28  13.85  14.10  13.69  13.97   9.637255   31061200        NaN
# 5   2017-05-02  14.06  14.34  13.85  13.99   9.651050   37830100        NaN
# 6   2017-05-03  14.04  14.25  13.95  14.16   9.768325   38357600        NaN
# 7   2017-05-04  14.00  14.00  13.58  13.60   9.382009   37695400        NaN
# 8   2017-05-05  13.69  14.21  13.66  14.21   9.802819   32788100  14.003333
# 9   2017-05-08  14.13  14.35  13.98  14.08   9.713138   36464300  14.008889
# 10  2017-05-09  14.15  14.24  14.04  14.14   9.754528   28008600  13.986667
# 11  2017-05-10  14.34  14.75  14.31  14.73  10.161540   46271700  14.067778
# 12  2017-05-11  14.88  14.92  14.64  14.82  10.223629   29318000  14.188889
# 13  2017-05-12  15.50  15.58  15.35  15.45  10.658237   83518200  14.353333
# 14  2017-05-15  15.77  15.87  15.65  15.68  10.816903   46914700  14.541111
# 15  2017-05-16  15.77  15.78  15.52  15.70  10.830700   34469300  14.712222
# 16  2017-05-17  15.56  15.72  15.51  15.61  10.768613   30023400  14.935556
# 17  2017-05-18  12.45  14.00  12.45  13.15   9.071572  142924900  14.817778
# 18  2017-05-19  13.75  13.90  13.46  13.62   9.395804   70983900  14.766667
# 19  2017-05-22  13.35  13.51  13.00  13.40   9.244037   55014900  14.684444
#
#         MM_17
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
# 13        NaN
# 14        NaN
# 15        NaN
# 16  14.484706
# 17  14.432941
# 18  14.390588
# 19  14.355294

# %%
close= go.Scatter(
    x=df.Date,
    y=df.Close,
    name='PETR4 Close',
    line= dict(color= '#330000'),
    opacity= 0.8
)
MM_9= go.Scatter(
    x=df.Date,
    y=df.MM_9,
    name='Média móvel 9 períodos',
    line= dict(color= '#FF8000'),
    opacity= 0.8
)
MM_17= go.Scatter(
    x=df.Date,
    y=df.MM_17,
    name='Média móvel 17 períodos',
    line= dict(color= '#FF8000'),
    opacity= 0.8
)
data=[close, MM_9, MM_17]
py.iplot(data)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0cff28bd-af44-4245-ad45-9d32fac18027" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0cff28bd-af44-4245-ad45-9d32fac18027")) {                    Plotly.newPlot(                        "0cff28bd-af44-4245-ad45-9d32fac18027",                        [{"line":{"color":"#330000"},"name":"PETR4 Close","opacity":0.8,"x":["2017-04-24","2017-04-25","2017-04-26","2017-04-27","2017-04-28","2017-05-02","2017-05-03","2017-05-04","2017-05-05","2017-05-08","2017-05-09","2017-05-10","2017-05-11","2017-05-12","2017-05-15","2017-05-16","2017-05-17","2017-05-18","2017-05-19","2017-05-22","2017-05-23","2017-05-24","2017-05-25","2017-05-26","2017-05-29","2017-05-30","2017-05-31","2017-06-01","2017-06-02","2017-06-05","2017-06-06","2017-06-07","2017-06-08","2017-06-09","2017-06-12","2017-06-13","2017-06-14","2017-06-15","2017-06-16","2017-06-19","2017-06-20","2017-06-21","2017-06-22","2017-06-23","2017-06-26","2017-06-27","2017-06-28","2017-06-29","2017-06-30","2017-07-03","2017-07-04","2017-07-05","2017-07-06","2017-07-07","2017-07-10","2017-07-11","2017-07-12","2017-07-13","2017-07-14","2017-07-17","2017-07-18","2017-07-19","2017-07-20","2017-07-21","2017-07-24","2017-07-25","2017-07-26","2017-07-27","2017-07-28","2017-07-31","2017-08-01","2017-08-02","2017-08-03","2017-08-04","2017-08-07","2017-08-08","2017-08-09","2017-08-10","2017-08-11","2017-08-14","2017-08-15","2017-08-16","2017-08-17","2017-08-18","2017-08-21","2017-08-22","2017-08-23","2017-08-24","2017-08-25","2017-08-28","2017-08-29","2017-08-30","2017-08-31","2017-09-01","2017-09-04","2017-09-05","2017-09-06","2017-09-07","2017-09-08","2017-09-11","2017-09-12","2017-09-13","2017-09-14","2017-09-15","2017-09-18","2017-09-19","2017-09-20","2017-09-21","2017-09-22","2017-09-25","2017-09-26","2017-09-27","2017-09-28","2017-09-29","2017-10-02","2017-10-03","2017-10-04","2017-10-05","2017-10-06","2017-10-09","2017-10-10","2017-10-11","2017-10-12","2017-10-13","2017-10-16","2017-10-17","2017-10-18","2017-10-19","2017-10-20","2017-10-23","2017-10-24","2017-10-25","2017-10-26","2017-10-27","2017-10-30","2017-10-31","2017-11-01","2017-11-02","2017-11-03","2017-11-06","2017-11-07","2017-11-08","2017-11-09","2017-11-10","2017-11-13","2017-11-14","2017-11-15","2017-11-16","2017-11-17","2017-11-20","2017-11-21","2017-11-22","2017-11-23","2017-11-24","2017-11-27","2017-11-28","2017-11-29","2017-11-30","2017-12-01","2017-12-04","2017-12-05","2017-12-06","2017-12-07","2017-12-08","2017-12-11","2017-12-12","2017-12-13","2017-12-14","2017-12-15","2017-12-18","2017-12-19","2017-12-20","2017-12-21","2017-12-22","2017-12-25","2017-12-26","2017-12-27","2017-12-28","2017-12-29","2018-01-02","2018-01-03","2018-01-04","2018-01-05","2018-01-08","2018-01-09","2018-01-10","2018-01-11","2018-01-12","2018-01-15","2018-01-16","2018-01-17","2018-01-18","2018-01-19","2018-01-22","2018-01-23","2018-01-24","2018-01-25","2018-01-26","2018-01-29","2018-01-30","2018-01-31","2018-02-01","2018-02-02","2018-02-05","2018-02-06","2018-02-07","2018-02-08","2018-02-09","2018-02-14","2018-02-15","2018-02-16","2018-02-19","2018-02-20","2018-02-21","2018-02-22","2018-02-23","2018-02-26","2018-02-27","2018-02-28","2018-03-01","2018-03-02","2018-03-05","2018-03-06","2018-03-07","2018-03-08","2018-03-09","2018-03-12","2018-03-13","2018-03-14","2018-03-15","2018-03-16","2018-03-19","2018-03-20","2018-03-21","2018-03-22","2018-03-23","2018-03-26","2018-03-27","2018-03-28","2018-03-29","2018-04-02","2018-04-03","2018-04-04","2018-04-05","2018-04-06","2018-04-09","2018-04-10","2018-04-11","2018-04-12","2018-04-13","2018-04-16","2018-04-17","2018-04-18","2018-04-19","2018-04-20","2018-04-23","2018-04-24","2018-04-25","2018-04-26","2018-04-27","2018 ...

# %%
#média de 17 dias
df['MM_3']= df.Close.rolling(window=3).mean()

# %%
close= go.Scatter(
    x=df.Date,
    y=df.Close,
    name='PETR4 Close',
    line= dict(color= '#330000'),
    opacity= 0.8
)
MM_3= go.Scatter(
    x=df.Date,
    y=df.MM_3,
    name='Média móvel 3 períodos',
    line= dict(color= '#AF8F00'),
    opacity= 0.8
)
MM_9= go.Scatter(
    x=df.Date,
    y=df.MM_9,
    name='Média móvel 9 períodos',
    line= dict(color= '#FF8000'),
    opacity= 0.8
)
MM_17= go.Scatter(
    x=df.Date,
    y=df.MM_17,
    name='Média móvel 17 períodos',
    line= dict(color= '#FF8000'),
    opacity= 0.8
)
data=[close, MM_3, MM_9, MM_17]
py.iplot(data)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="