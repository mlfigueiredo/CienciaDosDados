# %% [markdown]
# <a href="https://colab.research.google.com/github/mlfigueiredo/CienciaDosDados/blob/main/Analise_Cesta_Basica_Algoritmo_Apriori.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #<font color= green> Análise de cesta básica com Algoritmo Apriori

# %% [markdown]
# #### **Association Rule Learning ou regras de associação**
#
#
# ---
#
#
#
# ---
#
# ![](http://www.hypertextbookshop.com/dataminingbook/public_version/artifacts/animation/chpt2interMsec1fig2.gif)

# %% [markdown]
# > ### A mineração de regras de associação é uma técnica para **identificar relações subjacentes** entre diferentes itens.
#
# >### Tomemos um exemplo de um Supermercado onde os clientes podem comprar uma variedade de itens. **Normalmente, há um padrão no que os clientes compram**. Por exemplo, mães com bebês compram produtos para bebês, como leite e fraldas.
#
# >### As donzelas podem comprar itens de maquiagem, enquanto os solteiros podem comprar **cervejas e batatas fritas** etc. Em suma, as transações envolvem um padrão.
#
# >### **Mais lucro pode ser gerado** se a relação entre os itens comprados em diferentes transações puder ser identificada.

# %% [markdown]
# ## Etapas a serem consideradas pela utilização do Apriori
#
# Várias etapas podem ser tomadas **para aumentar o lucro**. Por exemplo:
#
# > **1.** A e B podem ser colocados juntos para que quando um cliente comprar um produto ele não precise ir muito longe para comprar o outro produto.
#
# >**2.** As pessoas que compram um dos produtos podem ser direcionadas através de uma campanha publicitária para comprar o outro.
#
# > **3.** Descontos coletivos podem ser oferecidos nesses produtos se o cliente comprar os dois.
#
# > **4.** Ambos A e B podem ser embalados juntos.

# %% [markdown]
# # <font color = Blue>Algoritmo APRIORI </font>
#
# ### Apriori O Algoritmo Apriori é um algoritmo de Aprendizado de Máquina que é usado para obter informações sobre os relacionamentos estruturados entre os diferentes itens envolvidos.
#
# ### A **aplicação prática** mais proeminente do algoritmo é **recomendar produtos** com base nos produtos já presentes no carrinho do usuário

# %% [markdown]
# # <font color = Blue>Por dentro do Algoritmo  </font>

# %% [markdown]
# ### Existem três componentes (parâmetros) principais do algoritmo Apriori:
#
# **Suport** suporte
#
# **Confidence**  confiança
#
# **lift**  aumento

# %% [markdown]
# ## Pra entender na Prática:

# %% [markdown]
# Suponha que temos um registro de 1 mil transações de clientes e queremos encontrar o Suporte, Confiança e Elevação para dois itens, por exemplo, **hambúrgueres e ketchup.**
#
# De mil transações, 100 contêm ketchup enquanto 150 contêm um hambúrguer. Das 150 transações em que um hambúrguer é comprado, 50 transações também contêm ketchup. Usando esses dados, queremos encontrar o **suporte, a confiança e o aumento.**

# %% [markdown]
# ![](https://cienciadosdados.com/images/2022/09/ap1.png)

# %% [markdown]
# ![](https://cienciadosdados.com/images/2022/09/ap2.png)

# %% [markdown]
# # Etapas a serem seguidas:

# %% [markdown]
# ![](https://cienciadosdados.com/images/2022/09/ap3.png)

# %% [markdown]
# ![](http://www.bh1.com.br/wp-content/uploads/2018/04/logotipo-logomarca-walmart.gif)
#
# ![](https://i.gifer.com/Ovcl.gif)

# %% [markdown]
# # 1° Problema de Negócio
#
# Você foi promovido a Cientista de Dados do Walmart. Seu objetivo inicial é desenvolver um projeto, uma Máquina Preditiva para recomendação de posicionamento de produtos no site e nas prateleiras físicas do Hyper-Mercado.

# %% [markdown]
# # 2° Análise Exploratória de Dados

# %%
#Importação de pacotes
# !pip install apyori
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5974 sha256=47b4a7eb659f1d9cdd32d8e090b0db1507a89ec33aee5979f41c2f2cbe759005
#   Stored in directory: /root/.cache/pip/wheels/cb/f6/e1/57973c631d27efd1a2f375bd6a83b2a616c4021f24aab84080
# Successfully built apyori
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Market_Basket_Optimisation.csv', header = None)
dataset. head()
# Out:
#               0          1           2                 3             4   \
# 0         shrimp    almonds     avocado    vegetables mix  green grapes
# 1        burgers  meatballs        eggs               NaN           NaN
# 2        chutney        NaN         NaN               NaN           NaN
# 3         turkey    avocado         NaN               NaN           NaN
# 4  mineral water       milk  energy bar  whole wheat rice     green tea
#
#                  5     6               7             8             9   \
# 0  whole weat flour  yams  cottage cheese  energy drink  tomato juice
# 1               NaN   NaN             NaN           NaN           NaN
# 2               NaN   NaN             NaN           NaN           NaN
# 3               NaN   NaN             NaN           NaN           NaN
# 4               NaN   NaN             NaN           NaN           NaN
#
#                10         11     12     13             14      15  \
# ...

# %%
transactions = []
for i in range(0, 7501):
  transactions.append([str(dataset.values[i,j]) for j in range(0, 20)])

# %% [markdown]
# # 3° Processamento de Dados

# %%
transactions[1]
# Out:
# ['burgers',
#  'meatballs',
#  'eggs',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan',
#  'nan']

# %%
transactions
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers',
#   'meatballs',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chutney',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'avocado',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
# ...

# %%
transactions_1 = dataset.values.tolist()
transactions_1[1]
# Out:
# ['burgers',
#  'meatballs',
#  'eggs',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan]

# %%
for i in range(len(transactions_1)) :
    for j in range(len(transactions_1[i])) :
        transactions_1[i][j] = str(transactions_1[i][j])
transactions_1
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers',
#   'meatballs',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chutney',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'avocado',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
# ...

# %%
transactions_1
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers',
#   'meatballs',
#   'eggs',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['chutney',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan'],
#  ['turkey',
#   'avocado',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
#   'nan',
# ...

# %% [markdown]
# # 4° Construção de Máquinas Preditivas com Machine Learning

# %% [markdown]
# https://pypi.org/project/apyori/

# %%
from apyori import apriori
rules = apriori(transactions = transactions_1, min_support = 0.003, min_cofindence = 0.2, min_lift = 3, min_length = 2, max_length = 2)

# %% [markdown]
# ### Exibindo os primeiros resultados vindos diretamente da saída da função a priori

# %%
results = list(rules)

# %%
results
# Out:
# [RelationRecord(items=frozenset({'brownies', 'cottage cheese'}), support=0.0034662045060658577, ordered_statistics=[OrderedStatistic(items_base=frozenset({'brownies'}), items_add=frozenset({'cottage cheese'}), confidence=0.10276679841897232, lift=3.225329518580382), OrderedStatistic(items_base=frozenset({'cottage cheese'}), items_add=frozenset({'brownies'}), confidence=0.10878661087866107, lift=3.2253295185803816)]),
#  RelationRecord(items=frozenset({'light cream', 'chicken'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'chicken'}), items_add=frozenset({'light cream'}), confidence=0.07555555555555556, lift=4.843950617283951), OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.29059829059829057, lift=4.84395061728395)]),
# ...

# %% [markdown]
# ### Colocando os resultados bem organizados em um DataFrame do Pandas

# %%
def inspect(results):
    lhs         = [tuple(result[2][0][0])[0] for result in results]
    rhs         = [tuple(result[2][0][1])[0] for result in results]
    supports    = [result[1] for result in results]
    confidences = [result[2][0][2] for result in results]
    lifts       = [result[2][0][3] for result in results]
    return list(zip(lhs, rhs, supports, confidences, lifts))
resultsinDataFrame = pd.DataFrame(inspect(results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 'Confidence', 'Lift'])

# %% [markdown]
# ### Mostrando resultados sem ordenação

# %%
resultsinDataFrame
# Out:
#    Left Hand Side       Right Hand Side   Support  Confidence      Lift
# 0        brownies        cottage cheese  0.003466    0.102767  3.225330
# 1         chicken           light cream  0.004533    0.075556  4.843951
# 2        escalope  mushroom cream sauce  0.005733    0.072269  3.790833
# 3        escalope                 pasta  0.005866    0.073950  4.700812
# 4     fresh bread          tomato juice  0.004266    0.099071  3.259356
# 5      fresh tuna                 honey  0.003999    0.179641  3.785070
# 6   fromage blanc                 honey  0.003333    0.245098  5.164271
# 7     ground beef         herb & pepper  0.015998    0.162822  3.291994
# 8     ground beef          tomato sauce  0.005333    0.054274  3.840659
# 9     light cream             olive oil  0.003200    0.205128  3.114710
# 10      olive oil     whole wheat pasta  0.007999    0.121457  4.122410
# 11          pasta                shrimp  0.005066    0.322034  4.506672

# %% [markdown]
# ### Mostrando resultados ordenados

# %%
resultsinDataFrame.nlargest(n = 15, columns = 'Lift')
# Out:
#    Left Hand Side       Right Hand Side   Support  Confidence      Lift
# 6   fromage blanc                 honey  0.003333    0.245098  5.164271
# 1         chicken           light cream  0.004533    0.075556  4.843951
# 3        escalope                 pasta  0.005866    0.073950  4.700812
# 11          pasta                shrimp  0.005066    0.322034  4.506672
# 10      olive oil     whole wheat pasta  0.007999    0.121457  4.122410
# 8     ground beef          tomato sauce  0.005333    0.054274  3.840659
# 2        escalope  mushroom cream sauce  0.005733    0.072269  3.790833
# 5      fresh tuna                 honey  0.003999    0.179641  3.785070
# 7     ground beef         herb & pepper  0.015998    0.162822  3.291994
# 4     fresh bread          tomato juice  0.004266    0.099071  3.259356
# 0        brownies        cottage cheese  0.003466    0.102767  3.225330
# 9     light cream             olive oil  0.003200    0.205128  3.114710

# %% [markdown]
# # **Conclusão**
#
# O aspecto realmente bom da análise de associação é que ela é fácil de executar e relativamente fácil de interpretar.
#
# Se você não tivesse acesso ao python e a essa análise de associação, seria extremamente difícil encontrar esses padrões usando a análise básica do Excel.
#
# Com python, o processo de análise é relativamente simples e, como você está em python, tem acesso a todas as técnicas adicionais de visualização e ferramentas de análise de dados no ecossistema **python**.

# %% [markdown]
# # **FIM**

# %% [markdown]
# ##### **Fontes**
#
# https://stackabuse.com/association-rule-mining-via-apriori-algorithm-in-python/
#
# https://www.geeksforgeeks.org/implementing-apriori-algorithm-in-python/
#
# https://www.kaggle.com/code/sangwookchn/association-rule-learning-with-scikit-learn/notebook
#
# https://pbpython.com/market-basket-analysis.html#:~:text=Association%20rules%20are%20normally%20written,%7BBeer%7D%20is%20the%20consequent.
