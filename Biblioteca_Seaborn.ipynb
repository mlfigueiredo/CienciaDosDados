# %% [markdown]
# <a href="https://colab.research.google.com/github/mlfigueiredo/CienciaDosDados/blob/main/Biblioteca_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns

# %%
df= sns.load_dataset("tips")
df.head()
#Dataset pagamento de conta no restaurante e tamanho da refeição, valor da conta, valor da gorjeta, almoço ou jantar, dia e sexo
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill', y='tip', data=df, hue='smoker')

# %%
sns.relplot(x='total_bill', y='tip', data=df, hue='sex')

# %%
sns.relplot(x='total_bill', y='tip', data=df, hue='sex', style='sex' )

# %%
sns.relplot(x='total_bill', y='tip', data=df, hue='sex', style='smoker')

# %%
sns.relplot(x='total_bill', y='tip', data=df, hue='size')

# %%
sns.relplot(x='total_bill', y='tip', data=df, size='size')

# %%
sns.relplot(x='total_bill', y='tip', data=df, size='size', sizes=(15, 300), hue='size')

# %%
sns.scatterplot(x='total_bill', y='tip', data=df, style='time', hue='day')

# %%
import matplotlib.pyplot as plt
f, ax= plt.subplots(figsize=(15, 7))
sns.scatterplot(x='total_bill', y='tip', data=df, style='time', hue='day')

# %%
sns.palplot(sns.color_palette("Accent"))

# %%
sns.palplot(sns.color_palette("PuOr"))

# %%
sns.palplot(sns.color_palette("Blues"))

# %%
sns.relplot(x='total_bill', y='tip', data=df, size='size', sizes=(15, 300), hue='size', palette='Blues')

# %%
sns.catplot(x='sex', kind='count', palette='Set2', data=df)

# %%
sns.heatmap(df.corr(), annot=True, cmap='PiYG')

# %%
sns.set_palette('pastel')
sns.heatmap(df.corr(), annot=True)

# %%
sns.catplot(y='day', kind='count', palette='Set1', data=df)

# %%
sns.catplot(x='day', y='total_bill', palette='Set1', data=df, hue='sex')

# %%
sns.catplot(x='day', y='total_bill', kind='swarm', palette='Set1', hue='sex', data=df)

# %%
sns.catplot(x='day', order=['Sat', 'Sun', 'Fri', 'Thur'], y='total_bill', kind='swarm', palette='Set1', hue='sex', data=df)

# %%
sns.catplot(y='day', order=['Sat', 'Sun', 'Fri', 'Thur'], x='total_bill', kind='swarm', palette='Set1', hue='sex', data=df)

# %%
sns.lmplot(x='total_bill', y='tip', hue='sex', data=df)

# %%
sns.lmplot(x='total_bill', y='tip', hue='smoker', col='time', data=df)

# %%
sns.lmplot(x='total_bill', y='tip', hue='smoker', col='sex', data=df)

# %%
sns.lmplot(x='total_bill', y='tip', hue='smoker', col='day', data=df)

# %%
sns.lmplot(x='total_bill', y='tip', hue='smoker', col='time', data=df, line_kws={'lw':4}, scatter_kws={'s': 90, 'alpha': 0.5})

# %%
sns.lmplot(x='total_bill', y='tip', hue='smoker', col='time', row='sex', data=df)

# %%
sns.catplot(x='day', y='total_bill', kind='box', data=df)

# %%
sns.catplot(x='day', y='total_bill', kind='box', data=df, hue='smoker')

# %%
sns.catplot(x='day', y='total_bill', kind='box', data=df, hue='size')

# %%
sns.catplot(x='day', y='total_bill', data= df, kind='boxen')

# %%
sns.stripplot(x='day', y='total_bill', data=df, color='blue')

# %%
sns.catplot(x='day', y='total_bill', data= df, kind='boxen')
sns.stripplot(x='day', y='total_bill', data=df, color='blue')

# %%
sns.catplot(x='sex', y='total_bill', data= df, kind='boxen', col='time', height=5)

# %%
correlacao= df.corr()
ax= sns.heatmap(correlacao, annot=True)
