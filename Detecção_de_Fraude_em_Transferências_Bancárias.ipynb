# %% [markdown]
# <a href="https://colab.research.google.com/github/mlfigueiredo/CienciaDosDados/blob/main/Detec%C3%A7%C3%A3o_de_Fraude_em_Transfer%C3%AAncias_Banc%C3%A1rias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color='GREY'> Detecção de Fraude em Transferências Bancárias</font>

# %% [markdown]
# ![alt text](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSJBs0VgOyUFFSnB5ORdhFUsQAXo95WAYd3iw&usqp=CAU)
#
# ![alt text](https://mfaas.com/resources/wp-content/uploads/In-app-Event-Fraud.gif)
# ![alt text](https://i.pinimg.com/originals/ad/63/67/ad6367c47eebf1baeb5af6c160ce8366.gif)
#
# ###"Golpe em dados bancários pela internet **cresceu 43%** no Brasil"
# https://economia.ig.com.br/2020-07-28/golpe-em-dados-bancarios-pela-internet-cresceu-43-no-brasil-saiba-se-proteger.html

# %% [markdown]
# # 1° Qual o Problema de Negócio
#
# Esse conjunto de dados fictício possui transações de transferências entre contas de uma mesma Instituição Financeira. São mais de 200 mil registros de transferências, sendo 490 Fraudulentas, ou seja, não foram realizadas pelo dono da conta corrente. Temos 28 variáveis explicativas e a variável Classe é o Target e assume o valor 1 em caso de fraude e 0 em caso contrário.

# %% [markdown]
# # 2° Análise Exploratória dos Dados

# %%
# Bibliotecas utilizadas
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Bibliotecas utilizadas no Pré-Processamento dos Dados
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

# Bibliotecas utilizadas na Construção de Máquinas Preditivas
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier
import xgboost as xgb
import lightgbm as lgb

# Bibliotecas utilizadas na Avaliação das Máquinas
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_auc_score

# %%
# Lendo os Dados
df = pd.read_csv('/content/transferencias.csv')

# %%
# Informações dos Atributos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3973 entries, 0 to 3972
# Data columns (total 31 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Timestamp        3973 non-null   int64
#  1   pais             3973 non-null   float64
#  2   cidade           3973 non-null   float64
#  3   bairro           3973 non-null   float64
#  4   cep              3973 non-null   float64
#  5   ip               3973 non-null   float64
#  6   dia              3973 non-null   float64
#  7   hora             3973 non-null   float64
#  8   minuto           3973 non-null   float64
#  9   so               3973 non-null   float64
#  10  valor            3973 non-null   float64
#  11  antecedentes     3973 non-null   float64
#  12  reclamacoes      3973 non-null   float64
#  13  qtd_trans        3973 non-null   float64
#  14  crt              3973 non-null   float64
#  15  limite_global    3972 non-null   float64
#  16  tipo_crt         3972 non-null   float64
#  17  estabelecimento  3972 non-null   float64
#  18  contas           3972 non-null   float64
#  19  emprestimos      3972 non-null   float64
#  20  navegador        3972 non-null   float64
#  21  android          3972 non-null   float64
#  22  ios              3972 non-null   float64
#  23  compras          3972 non-null   float64
#  24  hist_navegacao   3972 non-null   float64
#  25  relacionamento   3972 non-null   float64
#  26  ind_seguranca    3972 non-null   float64
#  27  tempo_transacao  3972 non-null   float64
#  28  lim_crt          3972 non-null   float64
#  29  hist_saldo       3972 non-null   float64
#  30  Target           3972 non-null   float64
# dtypes: float64(30), int64(1)
# memory usage: 962.3 KB

# %%
# Visualizando algumas linhas
df.head()
# Out:
#    Timestamp      pais    cidade    bairro       cep        ip       dia  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
#
#        hora    minuto        so  ...   android       ios   compras  \
# 0  0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474
# 1 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288
# 2  0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412
# 3  0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321
# 4  0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458
#
#    hist_navegacao  relacionamento  ind_seguranca  tempo_transacao   lim_crt  \
# 0        0.066928        0.128539      -0.189115         0.133558 -0.021053
# 1       -0.339846        0.167170       0.125895        -0.008983  0.014724
# 2       -0.689281       -0.327642      -0.139097        -0.055353 -0.059752
# 3       -1.175575        0.647376      -0.221929         0.062723  0.061458
# 4        0.141267       -0.206010       0.502292         0.219422  0.215153
#
#    hist_saldo  Target
# 0      149.62     0.0
# 1        2.69     0.0
# 2      378.66     0.0
# 3      123.50     0.0
# 4       69.99     0.0
#
# [5 rows x 31 columns]

# %%
# Verificando valores missing
# (verificar linhas duplicadas)
df.isna().sum()
# Out:
# Timestamp          0
# pais               0
# cidade             0
# bairro             0
# cep                0
# ip                 0
# dia                0
# hora               0
# minuto             0
# so                 0
# valor              0
# antecedentes       0
# reclamacoes        0
# qtd_trans          0
# crt                0
# limite_global      1
# tipo_crt           1
# estabelecimento    1
# contas             1
# emprestimos        1
# navegador          1
# android            1
# ios                1
# compras            1
# hist_navegacao     1
# relacionamento     1
# ind_seguranca      1
# tempo_transacao    1
# lim_crt            1
# hist_saldo         1
# Target             1
# dtype: int64

# %%
# Eliminando os valores missing
df.dropna(inplace=True)

# %%
# Dando uma olhada na variável Target
df['Target'].value_counts()
sns.countplot(df['Target'])

# %%
# Explorando as correlações com o Target
df.corr()['Target'].sort_values(ascending=False)
# Out:
# Target             1.000000
# cep                0.049523
# navegador          0.040693
# compras            0.029490
# contas             0.029418
# antecedentes       0.028237
# limite_global      0.023122
# hist_saldo         0.020957
# android            0.015182
# minuto             0.012711
# ios                0.009997
# emprestimos        0.009215
# ip                 0.008328
# qtd_trans          0.004605
# relacionamento     0.003698
# ind_seguranca      0.001286
# hist_navegacao    -0.000591
# tempo_transacao   -0.002574
# tipo_crt          -0.002649
# lim_crt           -0.004981
# cidade            -0.017326
# dia               -0.022654
# bairro            -0.025113
# hora              -0.025777
# Timestamp         -0.026490
# estabelecimento   -0.032583
# so                -0.038498
# pais              -0.038919
# valor             -0.039520
# reclamacoes       -0.068039
# crt               -0.085663
# Name: Target, dtype: float64

# %%
df.corr(method='spearman')
# Out:
#                  Timestamp      pais    cidade    bairro       cep        ip  \
# Timestamp         1.000000 -0.028492  0.057477 -0.017228 -0.122649  0.046288
# pais             -0.028492  1.000000 -0.428826 -0.350253  0.147296 -0.180657
# cidade            0.057477 -0.428826  1.000000  0.107837  0.016803  0.305387
# bairro           -0.017228 -0.350253  0.107837  1.000000  0.135881 -0.051416
# cep              -0.122649  0.147296  0.016803  0.135881  1.000000 -0.117313
# ip                0.046288 -0.180657  0.305387 -0.051416 -0.117313  1.000000
# dia              -0.047727 -0.052823 -0.096633  0.030781  0.209093  0.077380
# hora              0.090197 -0.254229  0.431040  0.142535 -0.169725  0.395165
# minuto           -0.002540 -0.080314 -0.084548 -0.031632  0.099060 -0.034751
# so                0.085769 -0.057179 -0.086254 -0.020147 -0.230996 -0.062775
# valor            -0.142373  0.030970  0.035734  0.047781  0.319767 -0.098937
# antecedentes      0.037538  0.034078  0.034901  0.022231 -0.099862  0.041506
# reclamacoes       0.016010  0.027873 -0.026665 -0.018042  0.052098 -0.122351
# qtd_trans        -0.009461  0.095046 -0.008316 -0.041464  0.051666  0.040609
# crt               0.093411  0.069064  0.074392 -0.326033 -0.063576 -0.010073
# limite_global     0.113295  0.154984  0.095277 -0.191448 -0.123088  0.157082
# tipo_crt         -0.051786  0.116200  0.050596 -0.195432 -0.036111  0.042403
# estabelecimento  -0.071712 -0.022733 -0.050644  0.071933  0.327527 -0.315256
# contas            0.079938  0.003158 -0.019817 -0.103673 -0.148859  0.070734
# emprestimos      -0.019265 -0.033257  0.036851 -0.048513  0.033951  0.044668
# navegador         0.021069 -0.223779  0.139430  0.023999 -0.100202  0.159888
# android           0.098332 -0.077623 -0.069872  0.075948 -0.036566 -0.050258
# ios               0.121272 -0.077307 -0.067634  0.267557 -0.029544 -0.015064
# compras          -0.100263 -0.053324  0.013276 -0.023977  0.160490 -0.197858
# hist_navegacao    0.031266  0.003703 -0.001338  0.046744 -0.033197 -0.133840
# relacionamento   -0.038629  0.408446 -0.334313 -0.378318  0.062046 -0.097353
# ind_seguranca    -0.130219 -0.040945 -0.072156  0.047197  0.046810 -0.220841
# tempo_transacao   0.094234 -0.146190  0.289299 -0.001493 -0.174438  0.122683
# lim_crt          -0.022197 -0.019250  0.097664 -0.022809  0.071422 -0.143167
# hist_saldo       -0.122408 -0.067098 -0.450932  0.067973  0.179052 -0.380267
# Target           -0.027478 -0.035118 -0.000959 -0.015317  0.036370  0.007272
#
#                       dia      hora    minuto        so  ...   android  \
# Timestamp       -0.047727  0.090197 -0.002540  0.085769  ...  0.098332
# pais            -0.052823 -0.254229 -0.080314 -0.057179  ... -0.077623
# cidade          -0.096633  0.431040 -0.084548 -0.086254  ... -0.069872
# bairro           0.030781  0.142535 -0.031632 -0.020147  ...  0.075948
# cep              0.209093 -0.169725  0.099060 -0.230996  ... -0.036566
# ip               0.077380  0.395165 -0.034751 -0.062775  ... -0.050258
# dia              1.000000 -0.300355  0.441013 -0.006109  ...  0.033796
# hora            -0.300355  1.000000 -0.418469 -0.018176  ... -0.037575
# minuto           0.441013 -0.418469  1.000000 -0.070583  ... -0.031591
# so              -0.006109 -0.018176 -0.070583  1.000000  ...  0.014803
# valor            0.163274 -0.169331 -0.067819 -0.288652  ... -0.204652
# antecedentes    -0.101454  0.109710 -0.029536 -0.128744  ...  0.062356
# reclamacoes      0.001413 -0.112619  0.017724  0.144620  ...  0.117182
# qtd_trans       -0.001519  0.036820 -0.187162 -0.258852  ...  0.020925
# crt             -0.154813  0.001839  0.170364 -0.170025  ...  0.168618
# limite_global   -0.196166  0.144558 -0.195890 -0.034423  ...  0.064430
# tipo_crt        -0.068264 -0.106375  0.112587 -0.221582  ... -0.072986
# estabelecimento  0.053170 -0.257389  0.097327 -0.104668  ...  0.032899
# contas           0.037931 -0.010584  0.047579 -0.055248  ...  0.025445
# emprestimos      0.133799  0.003839  0.020961  0.047457  ... -0.003487
# navegador        0.004819  0.264692  0.005280  0.034068  ... -0.007840
# android          0.033796 -0.037575 -0.031591  0.014803  ...  1.000000
# ios              0.019769  0.136917 -0.029809  0.142419  ...  0.573580
# compras         -0.064979 -0.190494  0.118957 -0.193904  ... -0.219043
# hist_navegacao  -0.244360  0.027111 -0.085505  0.030642  ...  0.062395
# relacionamento   0.061485 -0.269241 -0.018730  0.141202  ...  0.004194
# ind_seguranca    0.101389 -0.236196  0.165062 -0.077898  ... -0.184585
# tempo_transacao -0.004258  0.059235  0.148826  0.117370  ...  0.032338
# lim_crt         -0.009811 -0.132686  0.167223 -0.154549  ...  0.058688
# hist_saldo       0.267365 -0.136951  0.062486 -0.120683  ...  0.099815
# Target          -0.033219 -0.015944  0.014456 -0.025252  ...  0.035166
#
#                       ios   compras  hist_navegacao  relacionamento  \
# Timestamp        0.121272 -0.100263        0.031266       -0.038629
# pais            -0.077307 -0.053324        0.003703        0.408446
# cidade          -0.067634  0.013276       -0.001338       -0.334313
# bairro           0.267557 -0.023977        0.046744       -0.378318
# cep             -0.029544  0.160490       -0.033197        0.062046
# ip              -0.015064 -0.197858       -0.133840       -0.097353
# dia              0.019769 -0.064979       -0.244360        0.061485
# hora             0.136917 -0.190494        0.027111       -0.269241
# minuto          -0.029809  0.118957       -0.085505       -0.018730
# so               0.142419 -0.193904        0.030642        0.141202
# valor           -0.133704  0.157315       -0.022013       -0.013066
# antecedentes     0.085034  0.125957        0.076998       -0.135096
# reclamacoes      0.094983  0.074498        0.036677        0.068690
# qtd_trans        0.040136 -0.005472       -0.000772        0.085691
# crt             -0.061154  0.084153        0.013559       -0.003007
# limite_global    0.068966  0.066542        0.016242       -0.067844
# tipo_crt        -0.285590  0.063406       -0.061572        0.097210
# estabelecimento  0.055516  0.220926        0.024438       -0.091621
# contas          -0.015735 -0.215580       -0.052867        0.065034
# emprestimos     -0.004566 -0.185036       -0.047380       -0.002879
# navegador        0.072419 -0.216378        0.056575       -0.109697
# android          0.573580 -0.219043        0.062395        0.004194
# ios              1.000000 -0.306728        0.054136       -0.038441
# compras         -0.306728  1.000000        0.092787       -0.275363
# hist_navegacao   0.054136  0.092787        1.000000       -0.039718
# relacionamento  -0.038441 -0.275363       -0.039718        1.000000
# ind_seguranca   -0.308780  0.212066       -0.031092       -0.095488
# tempo_transacao  0.118878 -0.016111       -0.071244       -0.095699
# lim_crt         -0.124703  0.105690        0.025636       -0.044048
# hist_saldo       0.014984  0.054329       -0.010452        0.063954
# Target           0.011784  0.001037       -0.004013        0.004395
#
#                  ind_seguranca  tempo_transacao   lim_crt  hist_saldo  \
# Timestamp            -0.130219         0.094234 -0.022197   -0.122408
# pais                 -0.040945        -0.146190 -0.019250   -0.067098
# cidade               -0.072156         0.289299  0.097664   -0.450932
# bairro                0.047197        -0.001493 -0.022809    0.067973
# cep                   0.046810        -0.174438  0.071422    0.179052
# ip                   -0.220841         0.122683 -0.143167   -0.380267
# dia                   0.101389        -0.004258 -0.009811    0.267365
# hora                 -0.236196         0.059235 -0.132686   -0.136951
# minuto                0.165062         0.148826  0.167223    0.062486
# so                   -0.077898         0.117370 -0.154549   -0.120683
# valor                 0.147371        -0.125798 -0.032101    0.124153
# antecedentes         -0.058696         0.018260 -0.069604   -0.127206
# reclamacoes          -0.024104         0.047885  0.037808   -0.023438
# qtd_trans             0.034629        -0.067189  0.056532    0.066588
# crt                  -0.093149         0.054398  0.041004   -0.097702
# limite_global        -0.119642         0.068480 -0.028389   -0.203109
# tipo_crt              0.268133        -0.090960  0.097437   -0.083953
# estabelecimento       0.043346         0.004734  0.089809    0.180749
# contas               -0.105316         0.073291  0.012589   -0.045586
# emprestimos           0.009865        -0.029188 -0.089004    0.057434
# navegador             0.071042         0.111430  0.139450    0.113987
# android              -0.184585         0.032338  0.058688    0.099815
# ios                  -0.308780         0.118878 -0.124703    0.014984
# compras               0.212066        -0.016111  0.105690    0.054329
# hist_navegacao       -0.031092        -0.071244  0.025636   -0.010452
# relacionamento       -0.095488        -0.095699 -0.044048    0.063954
# ind_seguranca         1.000000        -0.215412  0.092545    0.173224
# tempo_transacao      -0.215412         1.000000  0.375483   -0.279937
# lim_crt               0.092545         0.375483  1.000000    0.044969
# hist_saldo            0.173224        -0.279937  0.044969    1.000000
# Target                0.004561        -0.002750 -0.010248   -0.000475
#
#                    Target
# Timestamp       -0.027478
# pais            -0.035118
# cidade          -0.000959
# bairro          -0.015317
# cep              0.036370
# ip               0.007272
# dia             -0.033219
# hora            -0.015944
# minuto           0.014456
# so              -0.025252
# valor           -0.032592
# antecedentes     0.012538
# reclamacoes     -0.034569
# qtd_trans        0.004248
# crt             -0.037584
# limite_global    0.019086
# tipo_crt        -0.001380
# estabelecimento -0.004767
# contas           0.021033
# emprestimos      0.013634
# navegador        0.026436
# android          0.035166
# ios              0.011784
# compras          0.001037
# hist_navegacao  -0.004013
# relacionamento   0.004395
# ind_seguranca    0.004561
# tempo_transacao -0.002750
# lim_crt         -0.010248
# hist_saldo      -0.000475
# Target           1.000000
#
# [31 rows x 31 columns]

# %%
# Estatísticas descritivas das variáveis
df.describe()
# Out:
#          Timestamp         pais       cidade       bairro          cep  \
# count  3972.000000  3972.000000  3972.000000  3972.000000  3972.000000
# mean   1638.224320    -0.333640     0.308476     0.836894     0.013009
# std    1016.217141     1.352136     1.180507     0.981122     1.418904
# min       0.000000   -12.168192   -15.732974   -12.389545    -4.657545
# 25%     750.000000    -1.030830    -0.155758     0.287084    -0.908489
# 50%    1526.000000    -0.451438     0.409390     0.884228     0.099491
# 75%    2524.500000     1.070629     0.920877     1.433776     0.982710
# max    3623.000000     1.685314     6.118940     4.017561     6.013346
#
#                 ip          dia         hora       minuto           so  ...  \
# count  3972.000000  3972.000000  3972.000000  3972.000000  3972.000000  ...
# mean     -0.029243     0.052876     0.146726    -0.071273     0.055417  ...
# std       1.207777     1.286769     1.090854     1.294801     0.918921  ...
# min     -32.092129    -7.465603   -11.164794   -23.632502    -3.336805  ...
# 25%      -0.573860    -0.735939    -0.278836    -0.205378    -0.474080  ...
# 50%      -0.090452    -0.209928     0.162196     0.028901     0.031868  ...
# 75%       0.396756     0.449680     0.634358     0.299371     0.620945  ...
# max      10.658654    21.393069    34.303177     3.877662     6.450992  ...
#
#            android          ios      compras  hist_navegacao  relacionamento  \
# count  3972.000000  3972.000000  3972.000000     3972.000000     3972.000000
# mean      0.010574    -0.082815    -0.058484        0.029106        0.095278
# std       0.855909     0.635547     0.391158        0.603965        0.405989
# min     -11.273890    -5.707801    -7.996811       -2.162523       -2.322906
# 25%      -0.211797    -0.512547    -0.210615       -0.338940       -0.141891
# 50%      -0.053211    -0.064375    -0.069939        0.100635        0.108219
# 75%       0.102520     0.345393     0.062502        0.432692        0.361309
# max      15.631453     4.393846     4.095021        1.215279        1.727063
#
#        ind_seguranca  tempo_transacao      lim_crt   hist_saldo       Target
# count    3972.000000      3972.000000  3972.000000  3972.000000  3972.000000
# mean       -0.012623         0.044638     0.002639    65.000101     0.000504
# std         0.503818         0.352752     0.254136   213.688183     0.022437
# min        -1.338556        -5.336289    -2.909294     0.000000     0.000000
# 25%        -0.339998        -0.041461    -0.020983     2.265000     0.000000
# 50%        -0.025647         0.033751     0.021264    12.990000     0.000000
# 75%         0.288406         0.205736     0.087058    54.990000     0.000000
# max         3.463246         3.852046     4.157934  7712.430000     1.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# # 3° Pré-Processamento dos dados

# %% [markdown]
# * Há desbalanceamento da classe (target)?
#
# * Também pode ser complicado lidar com outliers se não entendermos o domínio e o contexto do problema o suficiente.

# %%
# Separando os dados para treinamento e teste da máquina preditiva
X = df.drop(['Target'], axis=1)
y = df['Target']

# %%
#Balanceamento da Classe (Target)
smt = SMOTE()

# %%
X, y = smt.fit_sample(X, y)

# %%
#Contagem do target depois do smote. Obs: Antes da contagem, para usar a função bincount, precisei converter de float para inteiro
yi = y.astype(int)
np.bincount(yi)
# Out:
# array([284315, 284315])

# %%
ax = sns.countplot(x=yi)

# %%
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.3, random_state=7,stratify=y)

# %% [markdown]
# # 4° Criando a Máquina Preditiva de Detecção de Fraude

# %% [markdown]
# #XGBoost

# %% [markdown]
# * Criamos a Máquina Preditiva e ajustamos o modelo aos dados que preparamos para o treinamento.
#
# * Em seguida, procedemos à classificação com os dados que preparamos para avaliação.
#
# * Por último, avaliamos o desempenho do modelo com as principais métricas de classificação.

# %%
# Construindo o Modelo
from xgboost import XGBClassifier
model = XGBClassifier()

# %%
# Treinando o Modelo
# Demora alguns minutinhos
model = model.fit(X_train, y_train)
model

# %%
# Passando novos dados (dados de teste) Para o modelo
y_predict = model.predict(X_val)

# %% [markdown]
# ## 5° Avaliando a Máquina Preditiva

# %%
# Comparando gabarito e Previsoes_da_Máquina
gabarito = pd.DataFrame({'Gabarito': y_val,'Previsoes_da_Máquina': y_predict})
gabarito

# %%
# Evaluate model
print('Classification metrics: \n', classification_report(y_val, y_predict))
print('Acurácia: \n', accuracy_score(y_val, y_predict))
#0.98684  F1 99%
print('Confusion Matrix: \n', confusion_matrix(y_val, y_predict))

# %% [markdown]
# #LightGBM

# %%
# Light GBM
train_data=lgb.Dataset(X_train,label=y_train)
#setting parameters for lightgbm
param = {'num_leaves':1000,         #número de folhas em uma árvore; padrão = 31; type = int
         'objective':'binary',     
         'max_depth':7,
         'learning_rate':.01,
         'max_bin':200}

param['metric'] = ['auc', 'binary_logloss']

#training our model using light gbm
num_round=50

lgbm=lgb.train(param,train_data,num_round)

# %%
# Passando novos dados (dados de teste) Para o modelo
y_predict = lgbm.predict(X_val)

# %% [markdown]
# ## 5° Avaliando a Máquina Preditiva

# %%
# Comparando gabarito e Previsoes_da_Máquina
gabarito = pd.DataFrame({'Gabarito': y_val,'Previsoes_da_Máquina': y_predict})
gabarito
# Out:
#         Gabarito  Previsoes_da_Máquina
# 0              0              0.304927
# 1              1              0.696817
# 2              0              0.344381
# 3              0              0.304927
# 4              1              0.696817
# ...          ...                   ...
# 170584         0              0.313116
# 170585         0              0.304927
# 170586         1              0.696817
# 170587         0              0.304927
# 170588         0              0.315973
#
# [170589 rows x 2 columns]

# %%
y_predict.size
# Out:
# 170589

# %%
#converting probabilities into 0 or 1
for i in range(0,170589):
    if y_predict[i]>=.5:       # setting threshold to .5
       y_predict[i]=1
    else:  
       y_predict[i]=0

# %%
# Evaluate model
print('Classification metrics: \n', classification_report(y_val, y_predict))
print('Acurácia: \n', accuracy_score(y_val, y_predict))
#0.9843  F1 98%
print('Confusion Matrix: \n', confusion_matrix(y_val, y_predict))

# %% [markdown]
# # Random Forest

# %%
# Construindo o Modelo
model = RandomForestClassifier()

# %%
# Treinando o Modelo
# Demora alguns minutinhos
model = model.fit(X_train, y_train)
model
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
# Passando novos dados (dados de teste) Para o modelo
y_predict = model.predict(X_val)

# %% [markdown]
# ## 5° Avaliando a Máquina Preditiva

# %%
# Comparando gabarito e Previsoes_da_Máquina
gabarito = pd.DataFrame({'Gabarito': y_val,'Previsoes_da_Máquina': y_predict})
gabarito

# %%
# Evaluate model
print('Classification metrics: \n', classification_report(y_val, y_predict))
print('Acurácia: \n', accuracy_score(y_val, y_predict))
print('Confusion Matrix: \n', confusion_matrix(y_val, y_predict))

# %% [markdown]
# ### **Resumão**
#
# * Geração de Hipóteses é muito importante para o sucesso do Projeto de Ciência de Dados
# * O tratamento de classes desbalanceadas é fundamental para a assertividade da Máquina Preditiva
# * Às vezes, Menos é Mais. O Random forest bateu XGB e LGBM.
